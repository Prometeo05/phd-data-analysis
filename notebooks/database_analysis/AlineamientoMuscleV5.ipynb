# %%
# Step 1: Install MUSCLE v5
# !wget https://github.com/rcedgar/muscle/releases/download/v5.1/muscle5.1.linux -O muscle
# !chmod +x muscle

# Step 2: Upload Your Sequence File
from google.colab import files
uploaded = files.upload()

# Step 3: Perform Multiple Sequence Alignment (MSA)
input_file = list(uploaded.keys())[0]  # Get the uploaded filename
output_file = "aligned_sequences.fasta"

# !./muscle -align {input_file} -output {output_file}

print("Alignment completed! Aligned sequences saved as:", output_file)

# Step 4: Verify Sequence Consistency
seq_lengths = []
with open(output_file, "r") as f:
    for line in f:
        if not line.startswith(">"):
            seq_lengths.append(len(line.strip()))

if len(set(seq_lengths)) == 1:
    print("✅ Alignment successful! All sequences have the same length.")
else:
    print("⚠️ Warning: Sequences still have variable lengths.")

# Step 5: Display a Preview of the Aligned Sequences
# !head {output_file}
# Out:
# --2025-05-12 22:58:20--  https://github.com/rcedgar/muscle/releases/download/v5.1/muscle5.1.linux
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-12 22:58:21 ERROR 404: Not Found.
#      <input type="file" id="files-31e7cc0d-a87b-425f-9bb7-c776889e6e40" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31e7cc0d-a87b-425f-9bb7-c776889e6e40">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...

# %%
# Step 1: Install MUSCLE v5
# !wget https://github.com/rcedgar/muscle/releases/download/v5.1/muscle5.1.linux -O muscle
# !chmod +x muscle

# Step 2: Upload Your Sequence File
from google.colab import files
uploaded = files.upload()

# Step 3: Perform Multiple Sequence Alignment (MSA)
input_file = list(uploaded.keys())[0]  # Get the uploaded filename
output_file = "aligned_sequences.fasta"

# Execute MUSCLE and check the return code
return_code = !./muscle -align {input_file} -output {output_file}

# Print the return code for debugging
print(f"MUSCLE return code: {return_code}")

# Raise an exception if MUSCLE failed
if return_code:
    raise RuntimeError(f"MUSCLE alignment failed with return code: {return_code}")

print("Alignment completed! Aligned sequences saved as:", output_file)

# Step 4: Verify Sequence Consistency
seq_lengths = []
with open(output_file, "r") as f:
    for line in f:
        if not line.startswith(">"):
            seq_lengths.append(len(line.strip()))

if len(set(seq_lengths)) == 1:
    print("✅ Alignment successful! All sequences have the same length.")
else:
    print("⚠️ Warning: Sequences still have variable lengths.")

# Step 5: Display a Preview of the Aligned Sequences
# !head {output_file}
# Out:
# --2025-05-12 22:59:28--  https://github.com/rcedgar/muscle/releases/download/v5.1/muscle5.1.linux
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-12 22:59:28 ERROR 404: Not Found.
#      <input type="file" id="files-1e97258b-58f7-44f8-b064-d1dd7fec67a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e97258b-58f7-44f8-b064-d1dd7fec67a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...

# %%
# Step 1: Install MUSCLE v5
# !wget https://github.com/rcedgar/muscle/releases/download/v5.1/muscle5.1.linux -O muscle
# !chmod +x muscle

# Step 2: Upload Your Sequence File
from google.colab import files
uploaded = files.upload()

# Step 3: Perform Multiple Sequence Alignment (MSA)
input_file = list(uploaded.keys())[0]  # Get the uploaded filename
output_file = "aligned_sequences.fasta"

# Execute MUSCLE and check the return code
# Escape special characters in the filename using shlex.quote
import shlex
return_code = !./muscle -align {shlex.quote(input_file)} -output {shlex.quote(output_file)}

# Print the return code for debugging
print(f"MUSCLE return code: {return_code}")

# Raise an exception if MUSCLE failed
if return_code:
    raise RuntimeError(f"MUSCLE alignment failed with return code: {return_code}")

print("Alignment completed! Aligned sequences saved as:", output_file)

# Step 4: Verify Sequence Consistency
seq_lengths = []
with open(output_file, "r") as f:
    for line in f:
        if not line.startswith(">"):
            seq_lengths.append(len(line.strip()))

if len(set(seq_lengths)) == 1:
    print("✅ Alignment successful! All sequences have the same length.")
else:
    print("⚠️ Warning: Sequences still have variable lengths.")

# Step 5: Display a Preview of the Aligned Sequences
# !head {output_file}
# Out:
# --2025-05-12 23:00:35--  https://github.com/rcedgar/muscle/releases/download/v5.1/muscle5.1.linux
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-05-12 23:00:35 ERROR 404: Not Found.
#      <input type="file" id="files-ff512c2e-c57b-4f6c-b82f-a008a2b5fedf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff512c2e-c57b-4f6c-b82f-a008a2b5fedf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...
